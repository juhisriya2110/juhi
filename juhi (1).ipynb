# %%
emp_id=1
name="Daniel"
salary=10000.56
print("My employee id is:",emp_id)
print("My name is:",name)
print("my salary is:",salary)
# Out:
# My employee id is: 1
# My name is: Daniel
# my salary is: 10000.56

# %%
emp_id=1
name="Daniel"
salary=10000.56
print("My employee id is:",emp_id)
print("My name is:",name)
print("My salary is:",salary)
print()
# Out:
# My employee id is: 1
# My name is: Daniel
# My salary is: 10000.56

# %%
emp_id=1
name="Daniel"
salary=10000.56
print("My employee id is:",emp_id)
print("My name is:",name)
print("My salary is:",salary)
print()
print("emp_id type is:",type(emp_id))
print("name type is:",type(name))
print("salary type is:",type(salary))
# Out:
# My employee id is: 1
# My name is: Daniel
# My salary is: 10000.56
#
# emp_id type is: <class 'int'>
# name type is: <class 'str'>
# salary type is: <class 'float'>

# %%
a=2345
print(a)
print(type(a))
# Out:
# 2345
# <class 'int'>

# %%
b=3456238923904239048902357
print(b)
print(type(b))
# Out:
# 3456238923904239048902357
# <class 'int'>

# %%
num=10384658.9
print(num)
print(type(num))
# Out:
# 10384658.9
# <class 'float'>

# %%
a=True
b=False
print(a)
print(b)
# Out:
# True
# False

# %%
a=None
print(a)
print(type(a))
# Out:
# None
# <class 'NoneType'>

# %%
name1="Juhi"
name2="Sravanthi"
name3="'sony'"
name4="""Durga"""
print(name1)
print(name2)
print(name3)
print(name4)
print(type(name1))
print(type(name2))
print(type(name3))
print(type(name4))
# Out:
# Juhi
# Sravanthi
# 'sony'
# Durga
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
values=[10,20,30,40,50,60]
print(values)
print(type(values))
# Out:
# [10, 20, 30, 40, 50, 60]
# <class 'list'>

# %%
values=(10,20,30,40,50,60,70)
print(values)
print(type(values))
# Out:
# (10, 20, 30, 40, 50, 60, 70)
# <class 'tuple'>

# %%
values={10,20,30,40}
print(values)
print(type(values))
# Out:
# {40, 10, 20, 30}
# <class 'set'>

# %%
details={1:"jeswanth",2:"anjani",3:"sathvika",4:"gowtham"}
print(details)
print(type(details))
# Out:
# {1: 'jeswanth', 2: 'anjani', 3: 'sathvika', 4: 'gowtham'}
# <class 'dict'>

# %%
a=range(7)
print(a)
print(type(a))
# Out:
# range(0, 7)
# <class 'range'>

# %%
a=range(1,10)
print(a)
# Out:
# range(1, 10)

# %%
r=range(10,15)
for value in r:
    print(value)
# Out:
# 10
# 11
# 12
# 13
# 14

# %% [markdown]
# #

# %%
a=20
b=40
c=a+b
print(c)
# Out:
# 60

# %%
a=20
b=2
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
# Out:
# 22
# 18
# 40
# 10.0
# 0
# 400
# 10

# %%
a=20
print(a)
a+=5
print(a)
# Out:
# 20
# 25

# %%
a=10
print(a)
print(-a)
# Out:
# 10
# -10

# %%
a=20
b=10
print(a>b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# True
# True
# False
# False
# True

# %%
import numpy as np
arr=np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
arr2=np.array([[1,2,3,4],[5,6,7,8]])
print(arr2)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
print(arr2.shape)
# Out:
# (2, 4)

# %%
print(arr2.dtype)
# Out:
# int64

# %%
type(arr2)
# Out:
# numpy.ndarray

# %%
zeros=np.zeros((3,3))
print(zeros)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
ones=np.ones((2,4))
print(ones)
# Out:
# [[1. 1. 1. 1.]
#  [1. 1. 1. 1.]]

# %%
range_arr=np.arange(1,10,2)
print(range_arr)
# Out:
# [1 3 5 7 9]

# %%
range_arr=np.arange(1,10,2)
print(range_arr)
# Out:
# [1 3 5 7 9]

# %%
lin=np.linspace(0,1,5,6)
print(lin)
# Out:
# [0.   0.25 0.5  0.75 1.  ]

# %%
arr=np.arange(6).reshape(2,3)
print(arr)
# Out:
# [[0 1 2]
#  [3 4 5]]

# %%
flat=arr.flatten()
print(flat)
# Out:
# [0 1 2 3 4 5]

# %%
print(arr.max())
print(arr.min())
# Out:
# 5
# 0

# %%
print(arr.sum())
# Out:
# 15

# %%
print(np.mean(arr))
print(np.median(arr))
print(np.std(arr))
# Out:
# 2.5
# 2.5
# 1.707825127659933

# %%
print(arr2[1,2])
# Out:
# 7

# %%
print(arr2[:,1])
# Out:
# [2 6]

# %%
a=np.array([1,2,3,4])
b=np.array([5,6,7,8])
print(a+b)
# Out:
# [ 6  8 10 12]

# %%
print(a*b)
# Out:
# [ 5 12 21 32]

# %%
mat1=np.array([[1,2],[3,4]])
mat2=np.array([[5,6],[7,8]])
print(np.dot(mat1,mat2))
# Out:
# [[19 22]
#  [43 50]]

# %%
print(mat1.T)
# Out:
# [[1 3]
#  [2 4]]

# %%
arr=np.array([1,2,2,3,3,3])
print(np.unique(arr))
# Out:
# [1 2 3]

# %%
arr=np.array([10,20,30,40])
print(arr[arr>20])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 arr=np.array([10,20,30,40])
#       2 print(arr[arr>20])
#
# NameError: name 'np' is not defined

# %%
arr=np.array([10,20,30,40])
print(arr[arr>20])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 arr=np.array([10,20,30,40])
#       2 print(arr[arr>20])
#
# NameError: name 'np' is not defined

# %%
import numpy as np
arr=np.array([10,20,30,40])
print(arr[arr>20])
# Out:
# [30 40]

# %%
arr[arr>25]=0
print(arr)
# Out:
# [10 20  0  0]

# %%
rand_int=np.random.randint(1,10,5)
print(rand_int)
# Out:
# [7 7 3 5 7]

# %%
rand_float=np.random.rand(3,2)
print(rand_float)
# Out:
# [[0.77113132 0.63605923]
#  [0.34740333 0.4117805 ]
#  [0.30975563 0.00320984]]

# %%
arr=np.arange(10)
np.random.shuffle(arr)
print(arr)
# Out:
# [1 0 2 4 3 5 6 9 8 7]

# %%
arr=np.array([4,1,2,3])
print(np.sort(arr))
# Out:
# [1 2 3 4]

# %%
a=np.array([[1,2],[3,4]])
b=np.array([[5,6]])
print(np.vstack((a,b)))
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
a=np.array([[1,2],[3,4]])
b=np.array([[5,6],[7,8]])
print(np.hstack((a,b)))
# Out:
# [[1 2 5 6]
#  [3 4 7 8]]

# %%
x=np.array([1,2,3])
y=np.array([1,5,7])
print(np.corrcoef(x,y))
# Out:
# [[1.         0.98198051]
#  [0.98198051 1.        ]]

# %%
np.save('array.npy',arr)
loaded=np.load('array.npy')
print(loaded)
# Out:
# [4 1 2 3]

# %%
import pandas as pd
s=pd.Series([10,20,30,40,50])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import pandas as pd
s=pd.Series([10,20,30,40,50,60])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
data={'Name':['Janet','Rosie'],'Age':[20,22]}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0  Janet   20
# 1  Rosie   22

# %%
print(df.head())
# Out:
#     Name  Age
# 0  Janet   20
# 1  Rosie   22

# %%
print(df.tail(3))
# Out:
#     Name  Age
# 0  Janet   20
# 1  Rosie   22
# 2   lily   23

# %%
import numpy as np
data={'Name':['Janet','Rosie','lily'],'Age':[20,22,np.nan]}
df=pd.DataFrame(data)
print(df.tail(2))
# Out:
#     Name   Age
# 1  Rosie  22.0
# 2   lily   NaN

# %%
print(df.columns)
print(df.info())
# Out:
# Index(['Name', 'Age'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     2 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 180.0+ bytes
# None

# %%
print(df.describe())
# Out:
#              Age
# count   2.000000
# mean   21.000000
# std     1.414214
# min    20.000000
# 25%    20.500000
# 50%    21.000000
# 75%    21.500000
# max    22.000000

# %%
print(df['Name'])
# Out:
# 0    Janet
# 1    Rosie
# 2     lily
# Name: Name, dtype: object

# %%
print(df[['Name','Age']])
# Out:
#     Name   Age
# 0  Janet  20.0
# 1  Rosie  22.0
# 2   lily  21.0

# %%
print(df[df['Age']>21])
# Out:
#     Name   Age
# 1  Rosie  22.0

# %%
print(df.sort_values(by='Age'))
# Out:
#     Name   Age
# 0  Janet  20.0
# 2   lily  21.0
# 1  Rosie  22.0

# %%
import numpy as np
df['Salary']=[40000,50000,np.nan]
print(df)
# Out:
#     Name   Age   Salary
# 0  Janet  20.0  40000.0
# 1  Rosie  22.0  50000.0
# 2   lily  21.0      NaN

# %%
df=df.drop('Salary',axis=1)
print(df)
# Out:
#     Name   Age
# 0  Janet  20.0
# 1  Rosie  22.0
# 2   lily  21.0

# %%
print(df.isnull())
# Out:
#     Name    Age
# 0  False  False
# 1  False  False
# 2  False  False

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())
df
# Out:
#     Name   Age
# 0  Janet  20.0
# 1  Rosie  22.0
# 2   lily  21.0

# %%
group=df.groupby('Name')['Age'].mean()
print(group)
# Out:
# Name
# Janet    20.0
# Rosie    22.0
# lily     21.0
# Name: Age, dtype: float64

# %%
data
# Out:
# {'Name': ['Janet', 'Rosie', 'lily'], 'Age': [20, 22, nan]}

# %%
import numpy as np
import pandas as pd
data={'Name':['John','Alice','sony'],'Age':[27,np.nan,29]}
df1=pd.DataFrame(data)
print(df1)
# Out:
#     Name   Age
# 0   John  27.0
# 1  Alice   NaN
# 2   sony  29.0

# %%
print(df1.isnull())
# Out:
#     Name    Age
# 0  False  False
# 1  False   True
# 2  False  False

# %%
df1['Age']=df1['Age'].fillna(df1['Age'].mean ())

# %%
df1
# Out:
#     Name   Age
# 0   John  27.0
# 1  Alice  28.0
# 2   sony  29.0

# %%
group=df.groupby('Name')['Age'].mean()
print(group)
# Out:
# Name
# Alice    28.0
# John     27.0
# sony     29.0
# Name: Age, dtype: float64

# %%
df1.groupby('Name').agg({'Age':['mean','max']})
print(df1)
# Out:
#     Name   Age
# 0   John  27.0
# 1  Alice  28.0
# 2   sony  29.0

# %%
df2=pd.DataFrame({'ID':[1,2],'Name':['A','B']})
df3=pd.DataFrame({'ID':[1,2],'Score':['90','80']})
merged=pd.merge(df2,df3,on='ID')
print(merged)
# Out:
#    ID Name Score
# 0   1    A    90
# 1   2    B    80

# %%
df4=pd.concat([df2,df3],axis=0)
print(df4)
# Out:
#    ID Name Score
# 0   1    A   NaN
# 1   2    B   NaN
# 0   1  NaN    90
# 1   2  NaN    80

# %%
pd.pivot_table(df,values='Age',index='Name',aggfunc='mean')
# Out:
#         Age
# Name
# Alice  28.0
# John   27.0
# sony   29.0

# %%
df.columns=['person','Years']
print(df)
# Out:
#   person  Years
# 0   John     27
# 1  Alice     28
# 2   sony     29

# %%
df1=df.reset_index(drop=True)
print(df1)
# Out:
#   person  Years
# 0   John     27
# 1  Alice     28
# 2   sony     29

# %%
df1=df.set_index('person')
print(df1)
# Out:
#         Years
# person
# John       27
# Alice      28
# sony       29

# %%
df1=df.drop_duplicates
print(df1)
# Out:
# <bound method DataFrame.drop_duplicates of   person  Years
# 0   John     27
# 1  Alice     28
# 2   sony     29>

# %%
df['Years']=df['Years'].astype(float)
print(df)
# Out:
#   person  Years
# 0   John   27.0
# 1  Alice   28.0
# 2   sony   29.0

# %%
df=pd.read_csv("StudentPerformance")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df=pd.read_csv("StudentPerformance")
#       2 print(df.head())
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9995                                 2               23.0
# 9996                                 5               58.0
 9, 372: 5, 373: 1, 374: 4, 375: 5, 376: 5, 377: 7, 378: 4, 379: 1, 380: 5, 381: 7, 382: 6, 383: 5, 384: 4, 385: 2, 386: 4, 387: 3, 388: 1, 389: 8, 390: 5, 391: 4, 392: 8, 393: 7, 394: 2, 395: 1, 396: 4, 397: 8, 398: 2, 399: 3, 400: 1, 401: 1, 402: 3, 403: 5, 404: 3, 405: 1, 406: 1, 407: 8, 408: 2, 409: 3, 410: 2, 411: 3, 412: 7, 413: 1, 414: 8, 415: 2, 416: 3, 417: 9, 418: 7, 419: 4, 420: 5, 421: 2, 422: 8, 423: 4, 424: 9, 425: 5, 426: 9, 427: 4, 428: 5, 429: 9, 430: 8, 431: 3, 432: 1, 433: 3, 434: 4, 435: 2, 436: 1, 437: 7, 438: 8, 439: 7, 440: 5, 441: 1, 442: 7, 443: 7, 444: 9, 445: 3, 446: 9, 447: 1, 448: 1, 449: 4, 450: 9, 451: 6, 452: 3, 453: 1, 454: 4, 455: 9, 456: 3, 457: 9, 458: 7, 459: 4, 460: 3, 461: 5, 462: 5, 463: 3, 464: 9, 465: 4, 466: 5, 467: 4, 468: 5, 469: 7, 470: 9, 471: 7, 472: 5, 473: 7, 474: 5, 475: 3, 476: 7, 477: 2, 478: 9, 479: 1, 480: 6, 481: 7, 482: 8, 483: 9, 484: 2, 485: 2, 486: 5, 487: 5, 488: 6, 489: 3, 490: 8, 491: 1, 492: 6, 493: 4, 494: 1, 495: 7, 496: 9, 497: 4, 498: 4, 499: 6, 500: 3, 501: 6, 502: 7, 503: 3, 504: 7, 505: 3, 506: 2, 507: 4, 508: 8, 509: 9, 510: 7, 511 ...

# %%
df['Date']=pd.to_datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df['Date']=pd.to_datetime(df['Date'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Date'

# %%
import matplotlib.pyplot as plt
x=[5,6]
y=[5,6]
plt.plot(x,y)
plt.show()

# %%
x=[5,4]
y=[5,6]
plt.plot(x,y)
plt.show()

# %%
x=[6,7]
y=[8,9]
plt.plot(x,y,marker='*')
plt.show()

# %%
x=[2,4,8]
y=[6,7,8]
plt.plot(x,y,marker='*')
plt.show()

# %%
x=[5,6,9]
y=[5,6,20]
plt.title("Boss it is a line graph")
plt.plot(x,y,marker='*')
plt.show()

# %%
x=[5,6,7]
y=[7,8,18]
plt.title("A line graph")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.plot(x,y,marker='*')
plt.show()

# %%
x=[5,7,9]
y=[2,4,8]
p=[10,20,25]
plt.title("A line graph")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.plot(x,y,marker='*')
plt.plot(x,p,marker='*')
plt.show()

# %%
months=["Jan","Feb","Mar","Apr","May","June","July","Aug","Sep","Oct","Nov","Dec"]
sales=[23,45,56,78,213,45,78,89,99,100,101,130]
plt.title('A Bar Graph')
plt.xlabel('Month')
plt.ylabel('Product Sales')
plt.bar(months,sales)
plt.show()

# %%
months=["Jan","Feb","Mar","Apr","May","June","July","Aug","Sep","Oct","Nov","Dec"]
sales=[23,45,56,78,213,45,78,89,99,100,101,130]
plt.title('A Bar Graph')
plt.xlabel('Product Sales')
plt.ylabel('Month')
plt.barh(months,sales)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("StudentPerformance.csv")
plt.title('A Bar Graph')
plt.xlabel('Hours Studied')
plt.ylabel('Performance Index')
plt.bar(df.hours,df.performance)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24392\1829372542.py in ?()
#       3 df=pd.read_csv("StudentPerformance.csv")
#       4 plt.title('A Bar Graph')
#       5 plt.xlabel('Hours Studied')
#       6 plt.ylabel('Performance Index')
# ----> 7 plt.bar(df.hours,df.performance)
#       8 plt.show()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'hours'

# %%
months=["Jan","Feb","Mar","Apr","May","June","July","Aug","Sep","Oct","Nov","Dec"]
sales=[23,45,56,78,213,45,78,89,99,100,101,130]
plt.title('A Bar Graph')
plt.xlabel('Month')
plt.ylabel('Product Sales')
plt.bar(months,sales,width=1.0)
plt.show()

# %%
data=[11,12,14,18,21,7,5,10,16,15,13,15,16,12,17]
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Histogram Plot")
plt.hist(data,bins=20)
plt.show()

# %%
students=['Daniel','Prasad','Srinu']
points=[62,48,36]
plt.pie(points,labels=students)
plt.axis('equal')
plt.show()

# %%
students=['Daniel','Prasad','Srinu']
points=[62,48,36]
c=['y','r','b']
plt.pie(points,labels=students,colors=c,shadow=True,
explode=(0.05,0.05,0.05),autopct='%  1.1f%%')
plt.axis('equal')
plt.legend()
plt.show()

# %%
area=[1,2,3,4,5]
rice_packs=[10,20,30,40,50]
plt.xlabel('area')
plt.ylabel('rice packs')
plt.scatter(area,rice_packs)
plt.show()

# %%
area=[1,2,3,4.5,5,6]
rice_packs=[7,14,22,30,40,60]
plt.xlabel('area')
plt.ylabel('rice packs')
plt.scatter(area,rice_packs)
plt.show()

# %%
data=[10,20,30,40,50,60,70,80,90]
plt.boxplot(data)
plt.show()

# %%
import matplotlib.pyplot as plt
data=[10,20,30,40,50,90]
plt.boxplot(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
d={
    "Apple":[10,20,30,40],
    "Orange":[7,14,21,28],
    "Banana":[55,15,8,12],
    "Pear":[15,14,1,8]
}
i=['Basket1','Basket2','Basket3','Basket4']
df=pd.DataFrame(d,index=i)
plt.imshow(df,cmap="YlGnBu")
plt.colorbar()
plt.xticks(range(len(df)),df.columns)
plt.yticks(range(len(df)),df.index)
plt.show()

# %%
import seaborn as sns
df=sns.load_dataset('titanic')
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df=sns.load_dataset('titanic')
print(df.shape)
# Out:
# (891, 15)

# %%
df=sns.load_dataset('titanic')
print(df.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df=sns.load_dataset('titanic')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df=sns.load_dataset('titanic')
result=df['sex'].unique()
print(result)
# Out:
# ['male' 'female']
